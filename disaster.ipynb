# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
% matplotlib inline

# %%
df1=pd.read_csv("http://www.fema.gov/api/open/v1/DisasterDeclarationsSummaries.csv")

# %%
df1.head()
# Out:
#    disasterNumber  ihProgramDeclared  iaProgramDeclared  paProgramDeclared  \
# 0               1                  0                  1                  1
# 1              17                  0                  1                  1
# 2               3                  0                  1                  1
# 3              31                  0                  1                  1
# 4               9                  0                  1                  1
#
#    hmProgramDeclared state           declarationDate  fyDeclared disasterType  \
# 0                  1    GA  1953-05-02T00:00:00.000Z        1953           DR
# 1                  1    IA  1954-06-23T00:00:00.000Z        1954           DR
# 2                  1    LA  1953-05-29T00:00:00.000Z        1953           DR
# 3                  1    AK  1954-11-10T00:00:00.000Z        1955           DR
# 4                  1    TX  1953-06-19T00:00:00.000Z        1953           DR
#
# ...

# %%
df1.head(12)
# Out:
#     disasterNumber  ihProgramDeclared  iaProgramDeclared  paProgramDeclared  \
# 0                1                  0                  1                  1
# 1               17                  0                  1                  1
# 2                3                  0                  1                  1
# 3               31                  0                  1                  1
# 4                9                  0                  1                  1
# 5               35                  0                  1                  1
# 6               12                  0                  1                  1
# 7               37                  0                  1                  1
# 8               26                  0                  1                  1
# 9                5                  0                  1                  1
# 10              30                  0                  1                  1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48215 entries, 0 to 48214
# Data columns (total 18 columns):
# disasterNumber          48215 non-null int64
# ihProgramDeclared       48215 non-null int64
# iaProgramDeclared       48215 non-null int64
# paProgramDeclared       48215 non-null int64
# hmProgramDeclared       48215 non-null int64
# state                   48215 non-null object
# declarationDate         48215 non-null object
# fyDeclared              48215 non-null int64
# disasterType            48215 non-null object
# incidentType            48215 non-null object
# title                   48215 non-null object
# incidentBeginDate       48215 non-null object
# incidentEndDate         47809 non-null object
# disasterCloseOutDate    38097 non-null object
# declaredCountyArea      48015 non-null object
# placeCode               48015 non-null float64
# hash                    48215 non-null object
# lastRefresh             48215 non-null object
# ...

# %%
df1.lastRefresh
# Out:
# 0        2018-02-09T14:38:26.149Z
# 1        2018-02-09T14:38:26.191Z
# 2        2018-02-09T14:38:26.144Z
# 3        2018-02-09T14:38:26.182Z
# 4        2018-02-09T14:38:26.288Z
# 5        2018-02-09T14:38:26.292Z
# 6        2018-02-09T14:38:26.190Z
# 7        2018-02-09T14:38:26.194Z
# 8        2018-02-09T14:38:26.181Z
# 9        2018-02-09T14:38:26.287Z
# 10       2018-02-09T14:38:26.291Z
# 11       2018-02-09T14:38:26.189Z
# 12       2018-02-09T14:38:26.194Z
# 13       2018-02-09T14:38:26.180Z
# 14       2018-02-09T14:38:26.186Z
# 15       2018-02-09T14:38:26.291Z
# 16       2018-02-09T14:38:26.192Z
# 17       2018-02-09T14:38:26.173Z
# 18       2018-02-09T14:38:26.185Z
# 19       2018-02-09T14:38:26.289Z
# 20       2018-02-09T14:38:26.293Z
# 21       2018-02-09T14:38:26.193Z
# 22       2018-02-09T14:38:26.179Z
# 23       2018-02-09T14:38:26.186Z
# 24       2018-02-09T14:38:26.290Z
# 25       2018-02-09T14:38:26.293Z
# 26       2018-02-09T14:38:26.197Z
# ...

# %%
df1.disasterType.value_counts()
# Out:
# DR    34760
# EM    12115
# FM      950
# FS      390
# Name: disasterType, dtype: int64

# %%
df1.incidentType.value_counts().reset_index()
# Out:
#                index  incidentType
# 0    Severe Storm(s)         16002
# 1          Hurricane          9841
# 2              Flood          9617
# 3               Snow          3620
# 4               Fire          2970
# 5   Severe Ice Storm          1990
# 6            Tornado          1430
# 7            Drought          1292
# 8      Coastal Storm           463
# 9           Freezing           301
# 10             Other           297
# 11           Typhoon           119
# 12        Earthquake           105
# 13           Volcano            51
# 14    Fishing Losses            42
# 15     Mud/Landslide            31
# 16  Toxic Substances             9
# 17           Tsunami             9
# 18          Chemical             9
# 19   Dam/Levee Break             6
# 20       Human Cause             6
# 21         Terrorist             5

# %%
df1[df1.title == "FLOOD"]
# Out:
#     disasterNumber  ihProgramDeclared  iaProgramDeclared  paProgramDeclared  \
# 1               17                  0                  1                  1
# 2                3                  0                  1                  1
# 4                9                  0                  1                  1
# 6               12                  0                  1                  1
# 10              30                  0                  1                  1
# 13              21                  0                  1                  1
# 18              36                  0                  1                  1
# 21              27                  0                  1                  1
# 24              20                  0                  1                  1
# 26              52                  0                  1                  1
# 38              38                  0                  1                  1
# ...

# %%
df1.sort_values("fyDeclared",ascending=False)
# Out:
#        disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# 48214            4367                  0                  0
# 48055            3397                  0                  0
# 48067            4358                  0                  0
# 48066            4358                  0                  0
# 48065            4358                  0                  0
# 48064            5230                  0                  0
# 48063            4357                  1                  0
# 48062            4357                  1                  0
# 48061            4357                  1                  0
# 48060            4357                  1                  0
# 48059            4357                  1                  0
# 48058            3397                  0                  0
# 48057            3397                  0                  0
# 48056            3397                  0                  0
# 48054            3397                  0                  0
# ...
